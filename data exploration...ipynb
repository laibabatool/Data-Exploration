# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("height_weight_data.csv")
data
# Out:
#                     country  male_height  female_height  male_weight  \
# 0               Netherlands          184            170         87.9
# 1                Montenegro          183            170         90.4
# 2                   Estonia          182            168         89.9
# 3                   Denmark          182            169         86.8
# 4    Bosnia and Herzegovina          182            167         87.1
# ..                      ...          ...            ...          ...
# 121                   Nepal          164            152         60.5
# 122               Guatemala          164            151         69.1
# 123                   Yemen          163            154         62.5
# 124                    Laos          162            153         59.5
# 125             Timor-Leste          159            152         53.9
#
#      female_weight  male_bmi  female_bmi
# 0             73.2      26.1        25.3
# 1             75.3      27.0        26.2
# ...

# %%
data['male_height']
# Out:
# 0      184
# 1      183
# 2      182
# 3      182
# 4      182
#       ...
# 121    164
# 122    164
# 123    163
# 124    162
# 125    159
# Name: male_height, Length: 126, dtype: int64

# %%
a = str(data['male_height'])
print(type(a))
# Out:
# <class 'str'>

# %%
data.plot.scatter(x='country' , y='male_weight',color='green', marker='+')
plt.title("SCATTER PLOTTING")
plt.ylabel("MALE WEIGHT")
plt.xlabel("COUNTRY")
# Out:
# Text(0.5, 0, 'COUNTRY')

# %%
import seaborn as sns
sns.boxplot(data['female_height'])
sns.despine()
# Out:
# C:\Users\Laiba Batool\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fig = plt.figure()
a = fig.add_subplot(1,1,1)
a.hist(data['male_bmi'], bins=6)
plt.show()

# %%
test= data.groupby(['country','female_weight'])
test.size()
# Out:
# country         female_weight
# Afghanistan     57.9             1
# Albania         69.2             1
# Algeria         69.4             1
# American Samoa  98.1             1
# Andorra         71.7             1
#                                 ..
# United States   77.1             1
# Venezuela       68.5             1
# Vietnam         54.0             1
# Yemen           56.9             1
# Zimbabwe        64.6             1
# Length: 126, dtype: int64

# %%
a = plt.figure()
a
